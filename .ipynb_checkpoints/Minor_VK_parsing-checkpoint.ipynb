# %%
import vk
import pandas as pd
import numpy as np
from time import sleep

# %%
session = vk.Session(access_token = token) 
api = vk.API(session)

# %%
res = api.wall.getComments(owner_id = -29534144, post_id = 12925514, need_likes = 1, sort = 'asc', preview_length = 0, extended = 1, v = 5.103)

# %%
res

# %%
items = []
for i in range(0, 7):
    res = api.wall.getComments(owner_id = -29534144, post_id = 12925514, need_likes = 1, offset = 100*i, sort = 'asc', preview_length = 0, count = 100, extended = 1, v = 5.33)
    items_res = res['items']
    items.extend(items_res)
    sleep(0.5)

# %%
len(items)
# Out:
# 607

# %%
full_list = []
for item in items:
    try:
        L = [item['from_id'], item['id'], item['text'], item['date'],
            item['likes']['count'], item['reply_to_user']]
    except:
        L = [item['from_id'], item['id'], item['text'], item['date'],
            item['likes']['count'], np.nan]
    full_list.append(L)

# %%
df = pd.DataFrame(full_list)

# %%
df.columns = ['from_id', 'id', 'text', 'date', 'likes', 'reply_to_user']
df.head(10)
# Out:
#      from_id        id                                               text  \
# 0        100  12925517            Comment deleted by user or page manager
# 1  119181388  12925518  Мы ничего нового из его фильма не узнали, гово...
# 2  231731432  12925521                          да я не заразен, отВИЧаю!
# 3  392606018  12925522                            раз два три четыре пять
# 4  461778014  12925523           Лицо врача четыре пять шесть семь восемь
# 5  172520747  12925525                         и это сказал врач, пять...
# 6  450138623  12925526                        Беды с башкой три два пять.
# 7  119464564  12925527    Паровозик дыр дыр дыр, а в трубе тринадцать дыр
# 8   82037022  12925529  А потом опять выйдет опровержение, где все пер...
# 9  245962695  12925531            Квалификация... раз два три четыре пять
#
#          date  likes  reply_to_user
# 0  1581965870      0            NaN
# 1  1581965870    825            NaN
# 2  1581965878    990            NaN
# 3  1581965882     21            NaN
# 4  1581965885     19            NaN
# 5  1581965895   1024            NaN
# 6  1581965899     11            NaN
# 7  1581965905   1995            NaN
# 8  1581965907     12            NaN
# 9  1581965913     21            NaN

# %%
from datetime import datetime

def date_norm(date):
    d = datetime.fromtimestamp(date) # timestamp - UNIX-время в виде строки
    str_d = d.strftime("%Y-%m-%d %H:%M:%S") # %Y-%m-%d %H:%M:%S - год-месяц-день, часы:мин:сек
    return str_d

df['date'] = df['date'].apply(date_norm)

# %%
df
# Out:
#        from_id        id                                               text  \
# 0          100  12925517            Comment deleted by user or page manager
# 1    119181388  12925518  Мы ничего нового из его фильма не узнали, гово...
# 2    231731432  12925521                          да я не заразен, отВИЧаю!
# 3    392606018  12925522                            раз два три четыре пять
# 4    461778014  12925523           Лицо врача четыре пять шесть семь восемь
# ..         ...       ...                                                ...
# 602   71855909  12943057  [id90386938|Nik], да в основном сейчас путь ра...
# 603   71855909  12943067  [id18415003|Олег], самое смешное,что вы бы был...
# 604   71855909  12943079  Да,это очень печально,что врач настолько далек...
# 605   18415003  12943130  [id71855909|Марина], а с чего мне быть на мест...
# 606  486159060  12943784  Такого врача надо увольнять по профнепригодности.
#
#                     date  likes  reply_to_user
# 0    2020-02-18 01:57:50      0            NaN
# 1    2020-02-18 01:57:50    825            NaN
# 2    2020-02-18 01:57:58    990            NaN
# 3    2020-02-18 01:58:02     21            NaN
# 4    2020-02-18 01:58:05     19            NaN
# ..                   ...    ...            ...
# 602  2020-02-20 19:36:46      0     90386938.0
# 603  2020-02-20 19:39:47      0     18415003.0
# 604  2020-02-20 19:42:02      1            NaN
# 605  2020-02-20 19:53:04      0     71855909.0
# 606  2020-02-20 21:50:50      0            NaN
#
# [607 rows x 6 columns]

# %%
df.to_csv('vk_data.csv')

# %%
data
# Out:
#      Unnamed: 0    from_id        id  \
# 0             0        100  12925517
# 1             1  119181388  12925518
# 2             2  231731432  12925521
# 3             3  392606018  12925522
# 4             4  461778014  12925523
# ..          ...        ...       ...
# 602         602   71855909  12943057
# 603         603   71855909  12943067
# 604         604   71855909  12943079
# 605         605   18415003  12943130
# 606         606  486159060  12943784
#
#                                                   text                 date  \
# 0              Comment deleted by user or page manager  2020-02-18 01:57:50
# 1    Мы ничего нового из его фильма не узнали, гово...  2020-02-18 01:57:50
# 2                            да я не заразен, отВИЧаю!  2020-02-18 01:57:58
# 3                              раз два три четыре пять  2020-02-18 01:58:02
# 4             Лицо врача четыре пять шесть семь восемь  2020-02-18 01:58:05
# ..                                                 ...                  ...
# 602  [id90386938|Nik], да в основном сейчас путь ра...  2020-02-20 19:36:46
# 603  [id18415003|Олег], самое смешное,что вы бы был...  2020-02-20 19:39:47
# 604  Да,это очень печально,что врач настолько далек...  2020-02-20 19:42:02
# 605  [id71855909|Марина], а с чего мне быть на мест...  2020-02-20 19:53:04
# 606  Такого врача надо увольнять по профнепригодности.  2020-02-20 21:50:50
#
#      likes  reply_to_user
# 0        0            NaN
# 1      825            NaN
# 2      990            NaN
# 3       21            NaN
# 4       19            NaN
# ..     ...            ...
# 602      0     90386938.0
# 603      0     18415003.0
# 604      1            NaN
# 605      0     71855909.0
# 606      0            NaN
#
# [607 rows x 7 columns]

# %%
data.to_excel('vk_data.xlsx')
